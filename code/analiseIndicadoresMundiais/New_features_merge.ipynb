# %%
import pandas as pd
import pathlib

# %%
computed_features_folder = pathlib.Path('./new_features/')

# %% [markdown]
# # Small Graphs

# %%
#Já pega o target_graphs
small_graphs_features_files = list(computed_features_folder.glob("*graphs_*.csv"))

# %%
small = pd.read_csv(small_graphs_features_files[20])
small.head()
# Out:
#    city_name  city_id  streets_per_node_avg  node_density_km  \
# 0  gallarate     2519              2.725128       157.734956
# 1      galle     8935              2.363522       219.765099
# 2     galway     1584              2.264151       347.108671
# 3       gama     1215              2.878424       284.709911
# 4   gamagori    12944              3.173014       143.198108
#
#    intersection_density_km  edge_density_km  street_density_km  \
# 0               130.632489     37524.311736       21548.310956
# 1               144.851462     64451.735184       32926.845488
# 2               216.124267     59384.942102       31204.356773
# 3               249.562964     66491.870863       36251.610082
# 4               136.287366     41250.872010       21875.707928
#
#    1way_int_count  2way_int_count  3way_int_count  4way_int_count  \
# 0             772              55            3311             349
# 1            1084               2            1949             144
# 2            1300              14            2054              75
# 3            1253               9            7611            1273
# 4             147               3            2090             788
#
#    5way_int_count  6way_int_count  2way_int_prop  5way_int_prop  \
# 0             3.0             3.0       0.012241       0.000668
# 1             1.0             0.0       0.000629       0.000314
# 2             2.0             0.0       0.004064       0.000581
# 3             4.0             0.0       0.000887       0.000394
# 4            18.0             0.0       0.000985       0.005909
#
#    6way_int_prop  nodes_per_km_street  organic_prop  meshedness_coefficient
# 0       0.000668             0.007320      0.920009                0.623943
# 1       0.000000             0.006674      0.954374                0.638797
# 2       0.000000             0.011124      0.977558                0.572408
# 3       0.000000             0.007854      0.874076                0.795778
# 4       0.000000             0.006546      0.735130                1.005098

# %%
def merge_all_files(files_list:list) ->pd.DataFrame:
    final_df = pd.DataFrame() 
    for file in files_list:
        temp_df = pd.read_csv(file)
        final_df = pd.concat([final_df, temp_df])
    
    unwanted_cols = ['max_info_centrality', 'avg_info_centrality', 'max_betweenness_centrality',
                    'avg_betweenness_centrality', 'global_efficiency', 'avg_closeness_centrality']
    final_df.drop(unwanted_cols, axis=1, inplace=True)
    
    return final_df

# %%
small_graphs_feat_df = merge_all_files(small_graphs_features_files)

# %%
small_graphs_feat_df.head()
# Out:
#         city_name  city_id  streets_per_node_avg  node_density_km  \
# 0  6th of october     3881              3.074547       134.838226
# 1             9th     4032              3.123626        50.469652
# 2          aachen     2245              2.656357        99.808709
# 3         aalborg     2486              2.547955       143.889085
# 4          aarhus     2518              2.620561       141.914403
#
#    intersection_density_km  edge_density_km  street_density_km  \
# 0               129.955905     29758.680898       22894.690589
# 1                49.637735     21212.274383       19026.130382
# 2                78.028727     30088.459591       17058.828775
# 3               101.025472     33429.217757       19072.796647
# 4               104.059823     33875.790251       19395.066465
#
#    1way_int_count  2way_int_count  3way_int_count  ...  11way_int_prop  \
# 0             136               5            3061  ...             NaN
# 1               6               1             299  ...             NaN
# 2             896              89            2670  ...             NaN
# 3            1202              31            2240  ...             NaN
# 4            1645              57            3536  ...             NaN
#
#    12way_int_prop  13way_int_count  14way_int_count  15way_int_count  \
# 0             NaN              NaN              NaN              NaN
# 1             NaN              NaN              NaN              NaN
# 2             NaN              NaN              NaN              NaN
# 3             NaN              NaN              NaN              NaN
# 4             NaN              NaN              NaN              NaN
#
#    16way_int_count  13way_int_prop  14way_int_prop  15way_int_prop  \
# 0              NaN             NaN             NaN             NaN
# 1              NaN             NaN             NaN             NaN
# 2              NaN             NaN             NaN             NaN
# 3              NaN             NaN             NaN             NaN
# 4              NaN             NaN             NaN             NaN
#
#    16way_int_prop
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 39 columns]

# %%
len(small_graphs_feat_df)
# Out:
# 8625

# %%
small_graphs_feat_df
# Out:
#          city_name  city_id  streets_per_node_avg  node_density_km  \
# 0   6th of october     3881              3.074547       134.838226
# 1              9th     4032              3.123626        50.469652
# 2           aachen     2245              2.656357        99.808709
# 3          aalborg     2486              2.547955       143.889085
# 4           aarhus     2518              2.620561       141.914403
# ..             ...      ...                   ...              ...
# 36         tripoli     2971              2.725761       156.344411
# 37         tripoli     4361              2.935174       154.154972
# 38        valencia    13011              2.684766       518.205630
# 39        valencia     1911              3.067709       154.297093
# 40        valencia      821              2.866364       180.847551
#
#     intersection_density_km  edge_density_km  street_density_km  \
# 0                129.955905     29758.680898       22894.690589
# 1                 49.637735     21212.274383       19026.130382
# 2                 78.028727     30088.459591       17058.828775
# 3                101.025472     33429.217757       19072.796647
# 4                104.059823     33875.790251       19395.066465
# ..                      ...              ...                ...
# 36               127.211934     35735.175984       19253.268274
# 37               138.193548     39708.114677       23464.174717
# 38               409.562217    181532.630592       91469.875576
# 39               144.029493     30652.912539       21660.949503
# 40               150.153504     46389.633789       26011.516962
#
#     1way_int_count  2way_int_count  3way_int_count  ...  11way_int_prop  \
# 0              136               5            3061  ...             NaN
# 1                6               1             299  ...             NaN
# 2              896              89            2670  ...             NaN
# 3             1202              31            2240  ...             NaN
# 4             1645              57            3536  ...             NaN
# ..             ...             ...             ...  ...             ...
# 36            8089              17           31024  ...             NaN
# 37             345               3            2511  ...             NaN
# 38             139               0             455  ...             NaN
# 39            1886             275           20366  ...             NaN
# 40            4294              40           15774  ...             NaN
#
#     12way_int_prop  13way_int_count  14way_int_count  15way_int_count  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
# ..             ...              ...              ...              ...
# 36             NaN              NaN              NaN              NaN
# 37             NaN              NaN              NaN              NaN
# 38             NaN              NaN              NaN              NaN
# 39             NaN              NaN              NaN              NaN
# 40             NaN              NaN              NaN              NaN
#
#     16way_int_count  13way_int_prop  14way_int_prop  15way_int_prop  \
# 0               NaN             NaN             NaN             NaN
# 1               NaN             NaN             NaN             NaN
# 2               NaN             NaN             NaN             NaN
# 3               NaN             NaN             NaN             NaN
# 4               NaN             NaN             NaN             NaN
# ..              ...             ...             ...             ...
# 36              NaN             NaN             NaN             NaN
# 37              NaN             NaN             NaN             NaN
# 38              NaN             NaN             NaN             NaN
# 39              NaN             NaN             NaN             NaN
# 40              NaN             NaN             NaN             NaN
#
#     16way_int_prop
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 36             NaN
# 37             NaN
# 38             NaN
# 39             NaN
# 40             NaN
#
# [8625 rows x 39 columns]

# %%
len(small_graphs_feat_df.drop_duplicates(subset=['city_id']))
# Out:
# 8625

# %%
valores = small_graphs_feat_df['city_id'].value_counts()
valores[valores > 1]
# Out:
# Series([], Name: city_id, dtype: int64)

# %%
orig_small_graphs_df = pd.read_csv('./data/grafos_pequenos.csv')
orig_big_graphs_df = pd.read_csv('./data/grafos_grandes.csv')

# %%
orig_small_graphs_df.head()
# Out:
#           country country_iso   core_city  uc_id  cc_avg_dir  cc_avg_undir  \
# 0       indonesia         IDN       wates  12375    0.036690      0.038630
# 1          brazil         BRA  taquaralto   1186    0.024520      0.035016
# 2           china         CHN     xinqiao  12218    0.036481      0.045724
# 3        colombia         COL       yopal    687    0.016110      0.019414
# 4  czech_republic         CZE      pilsen   2886    0.032913      0.044298
#
#    cc_wt_avg_dir  cc_wt_avg_undir  circuity  elev_iqr  ...  prop_3way  \
# 0       0.004276         0.004359  1.065403      11.0  ...   0.743653
# 1       0.001195         0.001439  1.008276      18.0  ...   0.589312
# 2       0.001608         0.001723  1.016544       2.0  ...   0.486911
# 3       0.001072         0.001221  1.011106      16.0  ...   0.583149
# 4       0.001418         0.001758  1.047311      24.0  ...   0.536906
#
#    prop_deadend  self_loop_proportion  straightness  \
# 0      0.171990              0.000619      0.938612
# 1      0.043543              0.000000      0.991791
# 2      0.125654              0.000000      0.983725
# 3      0.056171              0.000460      0.989016
# 4      0.250421              0.001013      0.954826
#
#                             uc_names                     world_region  \
# 0                              Wates                             Asia
# 1                         Taquaralto  Latin America and the Caribbean
# 2  Xinqiao; Jiepai; Baqiao; Houxiang                             Asia
# 3                              Yopal  Latin America and the Caribbean
# 4                             Pilsen                           Europe
#
#       world_subregion  resident_pop  area  built_up_area
# 0  South-Eastern Asia        107046  28.0       4.717896
# 1       South America         90077  20.0       9.620359
# 2        Eastern Asia        104714  42.0      22.057976
# 3       South America        167421  16.0       5.645732
# 4      Eastern Europe        142248  53.0      28.124355
#
# [5 rows x 39 columns]

# %%
ids_to_add_at_small = {id for id in orig_small_graphs_df['uc_id'].tolist()}.difference(set(small_graphs_feat_df['city_id']))

# %%
ids_to_add_at_small
# Out:
# set()

# %%
{id for id in small_graphs_feat_df['city_id'].tolist()}.difference(set(orig_small_graphs_df['uc_id']))
# Out:
# {88,
#  101,
#  119,
#  350,
#  729,
#  821,
#  931,
#  1035,
#  1780,
#  1800,
#  1911,
#  1912,
#  2051,
#  2565,
#  2971,
#  2980,
#  5222,
#  7887,
#  8005,
#  12298}

# %% [markdown]
# Realized that I was computing features based on cities names other than its id. Had to fix this.

# %%
{' '.join(city.split('_')) for city in orig_small_graphs_df['core_city'].tolist()}.difference(set(small_graphs_feat_df['city_name']))
# Out:
# set()

# %%
len(orig_small_graphs_df)
# Out:
# 8605

# %%
valid_ids = orig_big_graphs_df['uc_id'].tolist()
wrong_cities_in_small = small_graphs_feat_df.query('city_id in @valid_ids')

# %%
wrong_ids = wrong_cities_in_small['city_id'].tolist()
small_graphs_feat_df.query('city_id not in @wrong_ids', inplace = True)

# %%
len(small_graphs_feat_df)
# Out:
# 8605

# %%
small_graphs_feat_df.isna().sum()
# Out:
# city_name                     0
# city_id                       0
# streets_per_node_avg          0
# node_density_km               0
# intersection_density_km       0
# edge_density_km               0
# street_density_km             0
# 1way_int_count                0
# 2way_int_count                0
# 3way_int_count                0
# 4way_int_count                0
# 5way_int_count                0
# 2way_int_prop                 0
# 5way_int_prop                 0
# nodes_per_km_street           0
# organic_prop                  0
# meshedness_coefficient        0
# 6way_int_count              300
# 6way_int_prop               300
# 7way_int_count             5064
# 7way_int_prop              5064
# 8way_int_count             7164
# 8way_int_prop              7164
# 9way_int_count             8324
# 9way_int_prop              8324
# 10way_int_count            8444
# 10way_int_prop             8444
# 11way_int_count            8545
# 12way_int_count            8545
# 11way_int_prop             8545
# 12way_int_prop             8545
# 13way_int_count            8565
# 14way_int_count            8565
# 15way_int_count            8585
# 16way_int_count            8585
# 13way_int_prop             8565
# 14way_int_prop             8565
# 15way_int_prop             8585
# 16way_int_prop             8585
# dtype: int64

# %%
small_graphs_merge_file_path = pathlib.Path('./data/small_graphs_new_feats_merge.csv')
small_graphs_feat_df.to_csv(small_graphs_merge_file_path, index=False)
