# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pathlib
# %matplotlib inline

# %% [markdown]
# # Carregando os dados de indicadores

# %%
data_folder = pathlib.Path("data")
indicators_file_path = data_folder / 'indicators.csv'
indicators_df = pd.read_csv(indicators_file_path)

# %%
indicators_df.head()
# Out:
#           country country_iso   core_city  uc_id  cc_avg_dir  cc_avg_undir  \
# 0       indonesia         IDN       wates  12375    0.036690      0.038630
# 1          brazil         BRA  taquaralto   1186    0.024520      0.035016
# 2           china         CHN     xinqiao  12218    0.036481      0.045724
# 3        colombia         COL       yopal    687    0.016110      0.019414
# 4  czech_republic         CZE      pilsen   2886    0.032913      0.044298
#
#    cc_wt_avg_dir  cc_wt_avg_undir  circuity  elev_iqr  ...  prop_3way  \
# 0       0.004276         0.004359  1.065403      11.0  ...   0.743653
# 1       0.001195         0.001439  1.008276      18.0  ...   0.589312
# 2       0.001608         0.001723  1.016544       2.0  ...   0.486911
# 3       0.001072         0.001221  1.011106      16.0  ...   0.583149
# 4       0.001418         0.001758  1.047311      24.0  ...   0.536906
#
#    prop_deadend  self_loop_proportion  straightness  \
# 0      0.171990              0.000619      0.938612
# 1      0.043543              0.000000      0.991791
# 2      0.125654              0.000000      0.983725
# 3      0.056171              0.000460      0.989016
# 4      0.250421              0.001013      0.954826
#
#                             uc_names                     world_region  \
# 0                              Wates                             Asia
# 1                         Taquaralto  Latin America and the Caribbean
# 2  Xinqiao; Jiepai; Baqiao; Houxiang                             Asia
# 3                              Yopal  Latin America and the Caribbean
# 4                             Pilsen                           Europe
#
#       world_subregion  resident_pop  area  built_up_area
# 0  South-Eastern Asia        107046  28.0       4.717896
# 1       South America         90077  20.0       9.620359
# 2        Eastern Asia        104714  42.0      22.057976
# 3       South America        167421  16.0       5.645732
# 4      Eastern Europe        142248  53.0      28.124355
#
# [5 rows x 39 columns]

# %%
indicators_meta_file_path = data_folder / 'metadata-indicators.csv'
indicators_meta_df = pd.read_csv(indicators_meta_file_path)

# %%
indicators_meta_df
# Out:
#                      indicator    type  \
# 0                      country  string
# 1                  country_iso  string
# 2                    core_city  string
# 3                        uc_id     int
# 4                   cc_avg_dir   float
# 5                 cc_avg_undir   float
# 6                cc_wt_avg_dir   float
# 7              cc_wt_avg_undir   float
# 8                     circuity   float
# 9                     elev_iqr   float
# 10                   elev_mean   float
# 11                 elev_median   float
# 12                  elev_range   float
# 13                    elev_std   float
# 14                  grade_mean   float
# 15                grade_median   float
# 16             intersect_count     int
# 17       intersect_count_clean     int
# 18  intersect_count_clean_topo     int
# 19                       k_avg   float
# 20                 length_mean   float
# 21               length_median   float
# 22                length_total   float
# 23                  node_count     int
# 24         orientation_entropy   float
# 25           orientation_order   float
# 26                pagerank_max   float
# 27                   prop_4way   float
# 28                   prop_3way   float
# 29                prop_deadend   float
# 30        self_loop_proportion   float
# 31                straightness   float
# 32        street_segment_count     int
# 33                    uc_names  string
# 34                world_region  string
# 35             world_subregion  string
# 36                resident_pop     int
# 37                        area   float
# 38               built_up_area   float
#
#                                           description
# 0                                   Main country name
# 1                Main country ISO 3166-1 alpha-3 code
# 2                         Urban center core city name
# 3                              Urban center unique ID
# 4           Average clustering coefficient (directed)
# 5         Average clustering coefficient (undirected)
# 6   Average clustering coefficient (weighted/direc...
# 7   Average clustering coefficient (weighted/undir...
# 8   Ratio of street lengths to straightline distances
# 9      Interquartile range of node elevations, meters
# 10                        Mean node elevation, meters
# 11                      Median node elevation, meters
# 12                   Range of node elevations, meters
# 13       Standard deviation of node elevations, meter
# 14               Mean absolute street grade (incline)
# 15             Median absolute street grade (incline)
# 16           Count of (undirected) edge intersections
# 17  Count of street intersections (after merging n...
# 18  Count of street intersections (after merging n...
# 19                   Average node degree (undirected)
# 20  Mean street segment length (undirected edges),...
# 21  Median street segment length (undirected edges...
# 22     Total street length (undirected edges), meters
# 23                                     Count of nodes
# 24                 Entropy of street network bearings
# 25       Orientation order of street network bearings
# 26             The maximum PageRank value of any node
# 27  Proportion of nodes that represent 4-way stree...
# 28  Proportion of nodes that represent 3-way stree...
# 29       Proportion of nodes that represent dead-ends
# 30            Proportion of edges that are self-loops
# 31                                       1 / circuity
# 32                Count of streets (undirected edges)
# 33  List of city names within this urban center (G...
# 34                 Major geographical region (UN WUP)
# 35                 Minor geographical region (UN WUP)
# 36            Total resident population in 2015 (GHS)
# 37  Area within urban center boundary polygon, km2...
# 38           Built-up surface area in 2015, km2 (GHS)

# %% [markdown]
# ## Quantidade de entradas

# %%
len(indicators_df)
# Out:
# 8914

# %% [markdown]
# ## Quantidade de nulos

# %%
indicators_df.isna().sum()
# Out:
# country                       0
# country_iso                   0
# core_city                     0
# uc_id                         0
# cc_avg_dir                    0
# cc_avg_undir                  0
# cc_wt_avg_dir                 0
# cc_wt_avg_undir               0
# circuity                      0
# elev_iqr                      0
# elev_mean                     0
# elev_median                   0
# elev_range                    0
# elev_std                      0
# grade_mean                    0
# grade_median                  0
# intersect_count               0
# intersect_count_clean         0
# intersect_count_clean_topo    0
# k_avg                         0
# length_mean                   0
# length_median                 0
# length_total                  0
# street_segment_count          0
# node_count                    0
# orientation_entropy           0
# orientation_order             0
# pagerank_max                  0
# prop_4way                     0
# prop_3way                     0
# prop_deadend                  0
# self_loop_proportion          0
# straightness                  0
# uc_names                      0
# world_region                  0
# world_subregion               0
# resident_pop                  0
# area                          0
# built_up_area                 0
# dtype: int64

# %%
indicators_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8914 entries, 0 to 8913
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   country                     8914 non-null   object
#  1   country_iso                 8914 non-null   object
#  2   core_city                   8914 non-null   object
#  3   uc_id                       8914 non-null   int64
#  4   cc_avg_dir                  8914 non-null   float64
#  5   cc_avg_undir                8914 non-null   float64
#  6   cc_wt_avg_dir               8914 non-null   float64
#  7   cc_wt_avg_undir             8914 non-null   float64
#  8   circuity                    8914 non-null   float64
#  9   elev_iqr                    8914 non-null   float64
#  10  elev_mean                   8914 non-null   float64
#  11  elev_median                 8914 non-null   float64
#  12  elev_range                  8914 non-null   float64
#  13  elev_std                    8914 non-null   float64
#  14  grade_mean                  8914 non-null   float64
#  15  grade_median                8914 non-null   float64
#  16  intersect_count             8914 non-null   int64
#  17  intersect_count_clean       8914 non-null   int64
#  18  intersect_count_clean_topo  8914 non-null   int64
#  19  k_avg                       8914 non-null   float64
#  20  length_mean                 8914 non-null   float64
#  21  length_median               8914 non-null   float64
#  22  length_total                8914 non-null   float64
#  23  street_segment_count        8914 non-null   int64
#  24  node_count                  8914 non-null   int64
#  25  orientation_entropy         8914 non-null   float64
#  26  orientation_order           8914 non-null   float64
#  27  pagerank_max                8914 non-null   float64
#  28  prop_4way                   8914 non-null   float64
#  29  prop_3way                   8914 non-null   float64
#  30  prop_deadend                8914 non-null   float64
#  31  self_loop_proportion        8914 non-null   float64
#  32  straightness                8914 non-null   float64
#  33  uc_names                    8914 non-null   object
#  34  world_region                8914 non-null   object
#  35  world_subregion             8914 non-null   object
#  36  resident_pop                8914 non-null   int64
#  37  area                        8914 non-null   float64
#  38  built_up_area               8914 non-null   float64
# dtypes: float64(26), int64(7), object(6)
# memory usage: 2.7+ MB

# %%
indicators_df.describe().T
# Out:
#                              count           mean           std           min  \
# uc_id                       8914.0    6326.825219  4.195580e+03      1.000000
# cc_avg_dir                  8914.0       0.033338  1.706829e-02      0.000000
# cc_avg_undir                8914.0       0.040118  2.108298e-02      0.000000
# cc_wt_avg_dir               8914.0       0.002085  3.577365e-03      0.000000
# cc_wt_avg_undir             8914.0       0.002266  3.629389e-03      0.000000
# circuity                    8914.0       1.052679  3.559030e-02      1.001810
# elev_iqr                    8914.0      19.951397  2.705749e+01      1.000000
# elev_mean                   8914.0     345.070347  4.874916e+02    -31.173765
# elev_median                 8914.0     343.092439  4.870768e+02    -35.000000
# elev_range                  8914.0      99.257797  1.158749e+02      3.000000
# elev_std                    8914.0      15.614275  1.900620e+01      0.827415
# grade_mean                  8914.0       0.023053  1.476613e-02      0.000571
# grade_median                8914.0       0.012015  9.317947e-03      0.000000
# intersect_count             8914.0    3534.778999  1.539541e+04      1.000000
# intersect_count_clean       8914.0    2985.385461  1.286495e+04      1.000000
# intersect_count_clean_topo  8914.0    3011.553960  1.297410e+04      1.000000
# k_avg                       8914.0       2.785104  2.733916e-01      1.363636
# length_mean                 8914.0     215.981850  2.385464e+02     36.830383
# length_median               8914.0     144.723044  1.916420e+02     24.685000
# length_total                8914.0  653056.054091  2.433144e+06   6017.301000
# street_segment_count        8914.0    5992.710231  2.613988e+04      3.000000
# node_count                  8914.0    4238.463653  1.847133e+04      4.000000
# orientation_entropy         8914.0       3.269087  3.075443e-01      1.329661
# orientation_order           8914.0       0.246141  2.091744e-01      0.001210
# pagerank_max                8914.0       0.010464  2.559928e-02      0.000004
# prop_4way                   8914.0       0.190716  1.204978e-01      0.000000
# prop_3way                   8914.0       0.623776  1.077333e-01      0.142857
# prop_deadend                8914.0       0.179742  9.246007e-02      0.003284
# self_loop_proportion        8914.0       0.001375  3.878675e-03      0.000000
# straightness                8914.0       0.950915  2.863873e-02      0.571227
# resident_pop                8914.0  349299.209334  1.307668e+06  50007.000000
# area                        8914.0      69.275746  2.268596e+02      4.000000
# built_up_area               8914.0      32.635446  1.360547e+02      1.000365
#
#                                      25%            50%            75%  \
# uc_id                        2415.250000    5973.500000   10627.750000
# cc_avg_dir                      0.023124       0.031077       0.040705
# cc_avg_undir                    0.026610       0.036271       0.049854
# cc_wt_avg_dir                   0.000854       0.001428       0.002340
# cc_wt_avg_undir                 0.000965       0.001609       0.002562
# circuity                        1.031809       1.046948       1.065216
# elev_iqr                        5.000000      12.000000      25.000000
# elev_mean                      34.171701     145.712597     436.678170
# elev_median                    32.000000     144.000000     436.000000
# elev_range                     27.000000      61.000000     127.000000
# elev_std                        4.330170      10.073242      19.832274
# grade_mean                      0.012859       0.019083       0.029360
# grade_median                    0.006000       0.010000       0.016000
# intersect_count               270.250000     978.000000    2483.750000
# intersect_count_clean         230.000000     844.500000    2116.750000
# intersect_count_clean_topo    231.250000     848.000000    2137.000000
# k_avg                           2.612129       2.796211       2.973742
# length_mean                    96.558248     132.472827     248.751745
# length_median                  67.666375      90.560500     148.145375
# length_total                98413.741250  209759.736000  465401.250250
# street_segment_count          460.500000    1643.000000    4194.000000
# node_count                    332.000000    1168.500000    2997.500000
# orientation_entropy             3.144029       3.369630       3.492604
# orientation_order               0.081043       0.185214       0.360033
# pagerank_max                    0.001160       0.002666       0.009013
# prop_4way                       0.097826       0.162162       0.257883
# prop_3way                       0.564247       0.635792       0.695565
# prop_deadend                    0.115873       0.168684       0.230819
# self_loop_proportion            0.000000       0.000149       0.001295
# straightness                    0.938777       0.955158       0.969171
# resident_pop                74669.750000  117552.000000  234268.000000
# area                           15.000000      26.000000      52.000000
# built_up_area                   3.629795       8.816780      22.071634
#
#                                      max
# uc_id                       1.313500e+04
# cc_avg_dir                  3.333333e-01
# cc_avg_undir                3.333333e-01
# cc_wt_avg_dir               1.662286e-01
# cc_wt_avg_undir             1.662286e-01
# circuity                    1.750617e+00
# elev_iqr                    5.810000e+02
# elev_mean                   3.933548e+03
# elev_median                 3.966000e+03
# elev_range                  1.713000e+03
# elev_std                    4.331807e+02
# grade_mean                  1.855733e-01
# grade_median                1.070000e-01
# intersect_count             7.742170e+05
# intersect_count_clean       6.403850e+05
# intersect_count_clean_topo  6.454600e+05
# k_avg                       3.656410e+00
# length_mean                 5.916520e+03
# length_median               5.821902e+03
# length_total                9.129764e+07
# street_segment_count        1.297317e+06
# node_count                  8.984300e+05
# orientation_entropy         3.582189e+00
# orientation_order           9.993357e-01
# pagerank_max                4.797306e-01
# prop_4way                   7.876712e-01
# prop_3way                   9.760000e-01
# prop_deadend                7.500000e-01
# self_loop_proportion        1.335234e-01
# straightness                9.981929e-01
# resident_pop                4.058988e+07
# area                        6.622000e+03
# built_up_area               4.632770e+03

# %% [markdown]
# ## Entradas por região geográfica

# %% [markdown]
# ### Região Maior

# %%
plt.figure(figsize=(6,3))
indicators_df['world_region'].value_counts().plot(kind='bar')
plt.title("Quantidade de cidades por região")
plt.show()

# %% [markdown]
# ## Região Menor

# %%
plt.figure(figsize=(6,3))
indicators_df['world_subregion'].value_counts().plot(kind='bar')
plt.title("Quantidade de cidades por sub-região")
plt.show()

# %% [markdown]
# # Entradas por país

# %% [markdown]
# Número de países diferentes com entradas

# %%
len(indicators_df['country'].value_counts())
# Out:
# 178

# %% [markdown]
# ## Distribuição

# %%
plt.figure(figsize=(8, 4))
plt.hist(indicators_df['country'].value_counts(), bins=20)
plt.title("Distribuição de cidades por país")
plt.show()

# %% [markdown]
# ## Top 30

# %%
plt.figure(figsize=(10,6))
indicators_df['country'].value_counts()[:30].plot(kind='bar')
plt.title("Quantidade de cidades por país (top 30)")
plt.show()

# %% [markdown]
# ## Bottom 30

# %%
plt.figure(figsize=(10,6))
indicators_df['country'].value_counts()[-30:].plot(kind='bar')
plt.title("Quantidade de cidades por país (bottom 30)")
plt.show()
